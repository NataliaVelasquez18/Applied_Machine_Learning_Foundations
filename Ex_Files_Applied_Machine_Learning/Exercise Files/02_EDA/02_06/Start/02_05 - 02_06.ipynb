# %% [markdown]
# ## EDA & Cleaning: Exploring categorical features
#
# Using the Titanic dataset from [this](https://www.kaggle.com/c/titanic/overview) Kaggle competition.
#
# This dataset contains information about 891 people who were on board the ship when departed on April 15th, 1912. As noted in the description on Kaggle's website, some people aboard the ship were more likely to survive the wreck than others. There were not enough lifeboats for everybody so women, children, and the upper-class were prioritized. Using the information about these 891 passengers, the challenge is to build a model to predict which people would survive based on the following fields:
#
# - **Name** (str) - Name of the passenger
# - **Pclass** (int) - Ticket class
# - **Sex** (str) - Sex of the passenger
# - **Age** (float) - Age in years
# - **SibSp** (int) - Number of siblings and spouses aboard
# - **Parch** (int) - Number of parents and children aboard
# - **Ticket** (str) - Ticket number
# - **Fare** (float) - Passenger fare
# - **Cabin** (str) - Cabin number
# - **Embarked** (str) - Port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# **This section focuses on exploring the `Sex`, `Cabin`, and `Embarked` features.**

# %% [markdown]
# ### Read in data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

titanic = pd.read_csv('../../../titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Drop all continuous features
cont_feat = ['PassengerId', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch', 'Fare']
titanic.drop(cont_feat, axis=1, inplace=True)
titanic.head()
# Out:
#    Survived     Sex            Ticket Cabin Embarked
# 0         0    male         A/5 21171   NaN        S
# 1         1  female          PC 17599   C85        C
# 2         1  female  STON/O2. 3101282   NaN        S
# 3         1  female            113803  C123        S
# 4         0    male            373450   NaN        S

# %% [markdown]
# ### Explore categorical features
#
# Explore `Sex`, `Cabin`, and `Embarked`.

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Sex       891 non-null    object
#  2   Ticket    891 non-null    object
#  3   Cabin     204 non-null    object
#  4   Embarked  889 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 34.9+ KB

# %%
titanic.groupby(titanic['Cabin'].isnull()).mean()
# Out:
#        Survived
# Cabin
# False  0.666667
# True   0.299854

# %%
titanic['Cabin_ind'] = np.where(titanic['Cabin'].isnull(), 0, 1)
titanic.head(10)
# Out:
#    Survived     Sex            Ticket Cabin Embarked  Cabin_ind
# 0         0    male         A/5 21171   NaN        S          0
# 1         1  female          PC 17599   C85        C          1
# 2         1  female  STON/O2. 3101282   NaN        S          0
# 3         1  female            113803  C123        S          1
# 4         0    male            373450   NaN        S          0
# 5         0    male            330877   NaN        Q          0
# 6         0    male             17463   E46        S          1
# 7         0    male            349909   NaN        S          0
# 8         1  female            347742   NaN        S          0
# 9         1  female            237736   NaN        C          0

# %% [markdown]
# ### Plot categorical features

# %%
for i, col in enumerate(['Cabin_ind', 'Sex', 'Embarked']):
    plt.figure(i)
    sns.catplot(x=col, y='Survived', data=titanic, kind='point', aspect=2, )

# %%
#we see clearly that women survived more than man, than peole with cabin survived mroe than the ones with no cabin and finally 
#we cannot say that people who embarked in C has more likelyhood to survive.  We need to use critial thinking and determine
#whether embarked in C is related to other variables or what happened. 
#we will use pivot tables in python
#we say "survived" in the parenthesis otherwise will will do all the columns, index=sex >>indicate the row labels, column, then we pass an #agregation function. The defalult is mean but we want to look at the distribution based on gender where people boarded. 

titanic.pivot_table("Survived", index="Sex", columns="Embarked", aggfunc="count")
# Out:
# Embarked   C   Q    S
# Sex
# female    73  36  203
# male      95  41  441

# %%
#here we can see S is big in comparison with the others.  Lots of males boarded there. So it explains why it has the lowest survival rate, the others are very similar and it does not tell us much
titanic.pivot_table("Survived", index="Cabin_ind", columns="Embarked", aggfunc="count")
# Out:
# Embarked    C   Q    S
# Cabin_ind
# 0          99  73  515
# 1          69   4  129

# %%
#we can see that for Q and S there are drastically more people withous cabins than with cabins. Given that we know that peoople with cabins were more likely to survive this would explain why C has higher survival rate. 
#we can conclude that cabin and sex have very strong correlation with survival , embarked does not have much new insights and it reveals things that we already knew so its repetitive
